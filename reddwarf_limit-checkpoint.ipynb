# %%
import numpy as np#load ice cube data
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
files=["IC40_exp_new.csv","IC59_exp_new.csv","IC79_exp_new.csv","IC86_I_exp_new.csv","IC86_II_exp_new.csv", 
       "IC86_III_exp_new.csv","IC86_IV_exp_new.csv","IC86_V_exp_new.csv","IC86_VI_exp.csv",
       "IC86_VII_exp.csv"]

# %%
data=np.loadtxt("IC40_exp_new.csv")
for name in files[1:]:#indexing the list
    da=np.loadtxt(name)
    data=np.vstack((data,da))#load everyfile
mjd,log10_E,Ang_err,RA,Dec,Azim,Zenith=data.T
len(RA)
# Out:
# 1134431

# %%
fields=[log10_E,RA,Dec,Ang_err]
print(Ang_err)
iceang=fields[3]
# Out:
# [0.48 0.62 0.56 ... 0.3  0.21 0.25]

# %%
print(fields)
# Out:
# [array([3.31, 5.17, 3.92, ..., 2.88, 2.98, 3.28]), array([203.024,  75.024,  97.501, ..., 308.127, 332.199, 213.309]), array([ 16.76 , -13.371,  11.29 , ...,  42.543,  44.72 ,   4.708]), array([0.48, 0.62, 0.56, ..., 0.3 , 0.21, 0.25])]

# %%
def ra_to_degrees(ra_hours, ra_minutes, ra_seconds):# Convert RA from degrees, minutes, seconds to degrees
    return (ra_hours * 15) + (ra_minutes / 4) + (ra_seconds / 240)
def dec_to_degrees(dec_degrees, dec_minutes, dec_seconds):# Convert Dec from degrees, minutes, seconds to degrees
    sign = 1 if dec_degrees >= 0 else -1
    return abs(dec_degrees) + (dec_minutes / 60) + (dec_seconds / 3600) * sign


v388_Cas_ra=(ra_to_degrees(1,3,19.8350))
v388_Cas_dec =(dec_to_degrees(62,21,55.8372)) 
print(v388_Cas_ra,v388_Cas_dec)

v547_Cas_ra=(ra_to_degrees(0,32,29.5078))
v547_Cas_dec =(dec_to_degrees(67,14,09.1390)) 
print(v547_Cas_ra,v547_Cas_dec)

v780_Tau_ra=(ra_to_degrees(5, 40, 25.7311))
v780_Tau_dec =(dec_to_degrees(24 ,48, 07.8631)) 
print(v780_Tau_ra,v780_Tau_dec)

v962_Tau_ra=(ra_to_degrees(5 ,45, 51.9441))
v962_Tau_dec =(dec_to_degrees(22, 52 ,47.3984)) 
print(v962_Tau_ra,v962_Tau_dec)

v1589_Tau_ra=(ra_to_degrees(20, 42, 49.1546))
v1589_Tau_dec =(dec_to_degrees(41, 22, 59.9732)) 
print(v1589_Tau_ra,v1589_Tau_dec)

GJ_1078_ra=(ra_to_degrees(5 ,23, 49.0464))
GJ_1078_dec =(dec_to_degrees(22 ,32, 38.7532)) 
print(GJ_1078_ra,GJ_1078_dec)

GJ_3684_ra=(ra_to_degrees(11 ,47, 5.1623))
GJ_3684_dec =(dec_to_degrees(70, 1, 58.6481)) 
print(GJ_3684_ra,GJ_3684_dec)

GJ_8511_ra=(ra_to_degrees(22, 12, 6.4164))
GJ_8511_dec =(dec_to_degrees(31, 33, 41.0764 )) 
print(GJ_8511_ra,GJ_8511_dec)

TVLM_513_46_ra=(ra_to_degrees(15 ,1 ,8.1864639648))
TVLM_513_46_dec=(dec_to_degrees(+22 ,50, 02.137869060))
print(TVLM_513_46_ra,TVLM_513_46_dec)

DG_CVn_ra=(ra_to_degrees(13, 31 ,46.6246175093))
DG_CVn_dec=(dec_to_degrees(+29 ,16, 36.681048898))
print(DG_CVn_ra,DG_CVn_dec)
# Out:
# 15.832645833333334 62.36551033333333
# 8.122949166666666 67.23587194444444
# 85.10721291666667 24.802184194444447
# 86.46643375 22.879832888888888
# 310.70481083333334 41.38332588888889
# 80.95436 22.54409811111111
# 176.77150958333334 70.03295780555555
# 333.026735 31.561410111111112
# 225.28411026652 22.833927185849998
# 202.9442692396221 29.27685584691611

# %%
RA1=([v388_Cas_ra,v547_Cas_ra,v780_Tau_ra,v962_Tau_ra,v1589_Tau_ra,GJ_1078_ra,GJ_3684_ra,GJ_8511_ra,TVLM_513_46_ra,DG_CVn_ra])
dec1=([v388_Cas_dec,v547_Cas_dec,v780_Tau_dec,v962_Tau_dec,v1589_Tau_dec,GJ_1078_dec,GJ_3684_dec,GJ_8511_dec,TVLM_513_46_dec,DG_CVn_dec])
print(RA1)
print(dec1)
# Out:
# [15.832645833333334, 8.122949166666666, 85.10721291666667, 86.46643375, 310.70481083333334, 80.95436, 176.77150958333334, 333.026735, 225.28411026652, 202.9442692396221]
# [62.36551033333333, 67.23587194444444, 24.802184194444447, 22.879832888888888, 41.38332588888889, 22.54409811111111, 70.03295780555555, 31.561410111111112, 22.833927185849998, 29.27685584691611]

# %%
for i in range(0,10):
    red_ra=RA1[i]
    red_dec=dec1[i]
    ice_ra=(fields[1])
    ice_dec=(fields[2])
    ra_icecube =np.radians(ice_ra)  # RA of IceCube sources
    ra_red_dwarf =np.radians (red_ra)  # RA of red dwarfs
    dec_icecube = np.radians(ice_dec)  # Dec of IceCube sources
    dec_red_dwarf = np.radians(red_dec)
    ra_diff=ra_icecube-ra_red_dwarf
    Ang_sep=np.arccos(np.sin(dec_icecube)*np.sin(dec_red_dwarf)+np.cos(dec_icecube)*np.cos(dec_red_dwarf)*np.cos(ra_diff))
    def sig( declcut):
        decdiff=np.abs(ice_dec-red_dec)
        nuind=np.nonzero(decdiff < declcut)
        sg=np.radians(iceang[nuind])**2
        Ang_sep1=(np.arccos((np.sin(dec_icecube[nuind])*np.sin(dec_red_dwarf)+np.cos(dec_icecube[nuind])*np.cos(dec_red_dwarf)*np.cos(ra_icecube[nuind]-ra_red_dwarf))))**2
        return ((np.exp(-1*Ang_sep1/(2*sg)))/(2*np.pi*sg))
    def bgs(band, twopi = True):
        if twopi == True:
            s_ang = (np.sin(np.radians(red_dec + band)) - np.sin(np.radians(red_dec - band)))*(2 * np.pi)
            return 1/s_ang
        else:
            s_ang = (np.sin(np.deg2rad(red_dec + band)) - np.sin(np.deg2rad(red_dec- band)))
            return 1/s_ang
    def P(x,N,S,B):
        nsN=x/N
        return nsN*S+(1-nsN)*B
    def TS(x,N,S,B):
        return 2*np.sum(np.log((P(x,N,S,B)/B)))
    declcut=5
    band=5
    B=bgs(band,twopi=True)
    S =(sig(declcut)) 
    decdiff=np.abs(ice_dec-red_dec)
    nuind=np.nonzero(decdiff < declcut)
    N=len(nuind[0])
    def ns_for_TSmax(S, B, N):
        declcut=5
        band=5
        B=bgs(band,twopi=True)
        S =(sig(declcut)) 
        nll = lambda x: -TS(x,N,S,B)
        soln = minimize(nll,6,bounds=((0,None),))
        ns = float(soln.x)
        return ns
    ns1=ns_for_TSmax(S, B, N)
    print(i,red_ra,red_dec,B,N,ns1,TS(ns1,N,S,B),sep="  |   ")
# Out:
# 0  |   15.832645833333334  |   62.36551033333333  |   1.9685019367324756  |   38319  |   0.0  |   0.0
# 1  |   8.122949166666666  |   67.23587194444444  |   2.3596758913955442  |   30491  |   0.0  |   0.0
# 2  |   85.10721291666667  |   24.802184194444447  |   1.0058248798012217  |   106736  |   6.00000000001027  |   0.3577263214432777
# 3  |   86.46643375  |   22.879832888888888  |   0.9910202717737763  |   112198  |   0.0  |   0.0
# 4  |   310.70481083333334  |   41.38332588888889  |   1.2169063579487758  |   70441  |   0.0  |   0.0
# 5  |   80.95436  |   22.54409811111111  |   0.9885926713348427  |   112995  |   20.391667854859417  |   2.3815255293413937
# 6  |   176.77150958333334  |   70.03295780555555  |   2.6738030923963665  |   26034  |   0.0  |   0.0
# 7  |   333.026735  |   31.561410111111112  |   1.07155367769104  |   90451  |   0.0  |   0.0
# 8  |   225.28411026652  |   22.833927185849998  |   0.9906856288284254  |   112301  |   0.0  |   0.0
# 9  |   202.9442692396221  |   29.27685584691611  |   1.046754275406722  |   95959  |   2.4203519748213447  |   0.05107264573354488

# %%
for i in range(0,10):
    red_ra=RA1[i]
    red_dec=dec1[i]
    ice_ra=(fields[1])
    ice_dec=(fields[2])
    ra_icecube =np.radians(ice_ra)  # RA of IceCube sources
    ra_red_dwarf =np.radians (red_ra)  # RA of red dwarfs
    dec_icecube = np.radians(ice_dec)  # Dec of IceCube sources
    dec_red_dwarf = np.radians(red_dec)
    ra_diff=ra_icecube-ra_red_dwarf
    Ang_sep=np.arccos(np.sin(dec_icecube)*np.sin(dec_red_dwarf)+np.cos(dec_icecube)*np.cos(dec_red_dwarf)*np.cos(ra_diff))
    def sig( declcut):
        decdiff=np.abs(ice_dec-red_dec)
        nuind=np.nonzero(decdiff < declcut)
        sg=np.radians(iceang[nuind])**2
        Ang_sep1=(np.arccos((np.sin(dec_icecube[nuind])*np.sin(dec_red_dwarf)+np.cos(dec_icecube[nuind])*np.cos(dec_red_dwarf)*np.cos(ra_icecube[nuind]-ra_red_dwarf))))**2
        return ((np.exp(-1*Ang_sep1/(2*sg)))/(2*np.pi*sg))
    def bgs(band, twopi = True):
        if twopi == True:
            s_ang = (np.sin(np.radians(red_dec + band)) - np.sin(np.radians(red_dec - band)))*(2 * np.pi)
            return 1/s_ang
        else:
            s_ang = (np.sin(np.deg2rad(red_dec + band)) - np.sin(np.deg2rad(red_dec- band)))
            return 1/s_ang
    def P(x,N,S,B):
        nsN=x/N
        return nsN*S+(1-nsN)*B
    def TS(x,N,S,B):
        return 2*np.sum(np.log((P(x,N,S,B)/B)))
    declcut=5
    band=5
    B=bgs(band,twopi=True)
    S =(sig(declcut)) 
    decdiff=np.abs(ice_dec-red_dec)
    nuind=np.nonzero(decdiff < declcut)
    N=len(nuind[0])
    def ns_for_TSmax(S, B, N):
        declcut=5
        band=5
        B=bgs(band,twopi=True)
        S =(sig(declcut)) 
        nll = lambda x: -TS(x,N,S,B)
        soln = minimize(nll,6,bounds=((0,None),))
        ns = float(soln.x)
        return ns
    ns_v=np.linspace(0, 60, 100)
    TS_values =( [TS(x, N, S, B) for x in ns_v])
    plt.plot( ns_v,TS_values)
    plt.plot(ns_v,TS_values)
#plt.text(x=3.5, y=5, s="V388 Cas", fontsize=12, color='black')
    plt.xlabel(r'$n_s$ (Number of signal events)')
    plt.ylabel('TS ')
    plt.grid(True)

# %%
for i in range(0,10):
    red_ra=RA1[i]
    red_dec=dec1[i]
    ice_ra=(fields[1])
    ice_dec=(fields[2])
    ra_icecube =np.radians(ice_ra)  # RA of IceCube sources
    ra_red_dwarf =np.radians (red_ra)  # RA of red dwarfs
    dec_icecube = np.radians(ice_dec)  # Dec of IceCube sources
    dec_red_dwarf = np.radians(red_dec)
    ra_diff=ra_icecube-ra_red_dwarf
    Ang_sep=np.arccos(np.sin(dec_icecube)*np.sin(dec_red_dwarf)+np.cos(dec_icecube)*np.cos(dec_red_dwarf)*np.cos(ra_diff))
    def sig( declcut):
        decdiff=np.abs(ice_dec-red_dec)
        nuind=np.nonzero(decdiff < declcut)
        sg=np.radians(iceang[nuind])**2
        Ang_sep1=(np.arccos((np.sin(dec_icecube[nuind])*np.sin(dec_red_dwarf)+np.cos(dec_icecube[nuind])*np.cos(dec_red_dwarf)*np.cos(ra_icecube[nuind]-ra_red_dwarf))))**2
        return ((np.exp(-1*Ang_sep1/(2*sg)))/(2*np.pi*sg))
    def bgs(band, twopi = True):
        if twopi == True:
            s_ang = (np.sin(np.radians(red_dec + band)) - np.sin(np.radians(red_dec - band)))*(2 * np.pi)
            return 1/s_ang
        else:
            s_ang = (np.sin(np.deg2rad(red_dec + band)) - np.sin(np.deg2rad(red_dec- band)))
            return 1/s_ang
    def P(x,N,S,B):
        nsN=x/N
        return nsN*S+(1-nsN)*B
    def TS(x,N,S,B):
        return 2*np.sum(np.log((P(x,N,S,B)/B)))
    declcut=5
    band=5
    B=bgs(band,twopi=True)
    S =(sig(declcut))  
    decdiff=np.abs(ice_dec-red_dec)
    nuind=np.nonzero(decdiff < declcut)
    N=len(nuind[0])
    def ns_for_TSmax(S, B, N):
        declcut=5
        band=5
        B=bgs(band,twopi=True)
        S =(sig(declcut)) 
        nll = lambda x: -TS(x,N,S,B)
        soln = minimize(nll,6,bounds=((0,None),))
        ns = float(soln.x)
        return ns
    row_result = [TS(x, N, S, B) for x in range(50)]
    print(f"Row {i+1}: {row_result}")
# Out:
# Row 1: [0.0, -0.17028549489208758, -0.35033390199858994, -0.539887172859699, -0.7387008204169334, -0.9465428713133498, -1.1631929231797162, -1.3884412941088782, -1.622088253430412, -1.8639433242012438, -2.1138246494303305, -2.371558414832601, -2.636978322008236, -2.909925106665332, -3.1902460971913738, -3.4777948094298137, -3.7724305740531276, -4.074018193309715, -4.382427624317905, -4.697533686391424, -5.019215790162779, -5.347357686504976, -5.681847233532892, -6.0225761799507325, -6.3694399635146155, -6.722337523186291, -7.081171123885215, -7.445846192792775, -7.8162711662711954, -8.192357346550134, -8.574018767420235, -8.961172068219765, -9.353736375505902, -9.751633191816747, -10.154786290998095, -10.56312161966633, -10.97656720424185, -11.395053063330204, -11.818511124903951, -12.246875148160433, -12.680080649464221, -13.11806483236898, -13.560766521286428, -14.008126098618572, -14.460085445122854, -14.916587883304317, -15.377578123643033, -15.843002213480123, -16.31280748843257, -16.786942526080882]
# Row 2: [0.0, -0.11178148274209682, -0.2427082015178224, -0.391635847612088, -0.5575448835679213, -0.7395218665342962, -0.9367442302260673, -1.1484677740502633, -1.374016293474344, -1.6127729201063035, -1.864172839134175, -2.127697125448469, -2.4028674950211766, -2.689241810776774, -2.9864102141527074, -3.2939917789036803, -3.6116316033586533, -3.9389982726030563, -4.2757816346110475, -4.621690843755448, -4.9764526335014025, -5.339809786000398, -5.711519771725973, -6.091353536557275, -6.479094417026857, -6.874537167526086, -7.277487085539008, -7.68775922301396, -8.105177673635062, -8.529574927260999, -8.960791283673114, -9.398674319357108, -9.843078401246878, -10.293864242558593, -10.7508984962622, -11.214053382326856, -11.683206345334398, -12.15823973945548, -12.639040538130669, -13.125500066098795, -13.617513751684768, -14.11498089744827, -14.617804467612604, -15.125890890661536, -15.639149875933754, -16.157494242787863, -16.680839761530265, -17.209105004946068, -17.74221120960405, -18.280082146215033]
# Row 3: [0.0, 0.11495994215153701, 0.20599530458591397, 0.27456565669507, 0.3219630167311225, 0.3493389792289805, 0.357726321422739, 0.34805641673966414, 0.3211734205055894, 0.27784593917866757, 0.21877671501240165, 0.14461072892883373, 0.055942031227332094, -0.04668046092775967, -0.16274801127505398, -0.29178780966101886, -0.43335929569929393, -0.5870509672654426, -0.7524775948374766, -0.9292777811965761, -1.1171118133779265, -1.315659764915303, -1.5246198130374742, -1.743706741244649, -1.972650602226366, -2.211195520769595, -2.459098618306719, -2.7161290442555908, -2.9820671012897497, -3.256703453431951, -3.5398384070196482, -3.831281257329501, -4.1308496922925935, -4.438369248107999, -4.75367281095586, -5.0766001596852774, -5.406997546334625, -5.744717309390883, -6.089617517577256, -6.441561640883491, -6.800418246260106, -7.166060715703359, -7.5383669852898665, -7.917219301742852, -8.302503997159913, -8.6941112783899, -9.091935031176773, -9.495872636775587, -9.905824801405387, -10.321695395521376]
# Row 4: [0.0, -0.18278626432200648, -0.38470775861047757, -0.6041186420926633, -0.8396453151177212, -1.0901260295284185, -1.3545666708343675, -1.6321077384540017, -1.9219992548273181, -2.223581400963116, -2.53626936218638, -2.8595413183370333, -3.1929288172074664, -3.536008977705146, -3.8883981148379414, -4.249746481480863, -4.619733896869674, -4.9980660843691975, -5.38447158333999, -5.7786991276413575, -6.180515407269564, -6.589703146711509, -7.006059446176327, -7.429394343075869, -7.859529558673439, -8.2962974012323, -8.739539802537408, -9.18910746789147, -9.644859123791697, -10.106660849651108, -10.574385482258947, -11.047912083285894, -11.52712546208321, -12.011915746382835, -12.502177995382326, -12.997811850017012, -13.498721215964293, -14.004813975977365, -14.516001727804655, -15.032199545220012, -15.553325759590352, -16.07930175967967, -16.610051808182163, -17.145502872802776, -17.6855844708136, -18.230228525645074, -18.779369234252734, -19.33294294459261, -19.890888041823736, -20.453144842782258]
# Row 5: [0.0, -0.24743457151384635, -0.5054701849018576, -0.7737020847513387, -1.0517598014137548, -1.3393028270025138, -1.6360169888161762, -1.9416113856985007, -2.2558157835772823, -2.5783783873178394, -2.909063924092906, -3.247651985591894, -3.593935586983481, -3.947719908774136, -4.308821192875627, -4.67706577058467, -5.052289202820523, -5.434335517295286, -5.82305652897385, -6.218311232761965, -6.6199652594012, -7.027890385894565, -7.441964094393112, -7.862069173122826, -8.288093354914013, -8.719928988423323, -9.157472739054871, -9.600625315654739, -10.049291220581656, -10.503378520561258, -10.96279863643123, -11.427466149328543, -11.897298622129512, -12.372216434766939, -12.852142631527574, -13.337002779901345, -13.826724839245555, -14.321239039176074, -14.820477765964474, -15.324375456796643, -15.832868501311546, -16.34589514923273, -16.863395424286807, -17.385311043216234, -17.911585340281484, -18.442163195954997, -18.97699097003863, -19.516016438955358, -20.059188736356777, -20.606458297269608]
# Row 6: [0.0, 0.2491977483339322, 0.4820621872595986, 0.6991496109789168, 0.9009805977874256, 1.0880432582488397, 1.2607961096724178, 1.4196706279284232, 1.5650735201477073, 1.6973887545087847, 1.8169793786278698, 1.924189152615058, 2.019344019737312, 2.102753433695975, 2.1747115597724487, 2.23549836392196, 2.2853806026479284, 2.324612724183497, 2.3534376910193373, 2.3720877316818774, 2.380785029410271, 2.3797423537305673, 2.3691636411143064, 2.3492445293404884, 2.320172850283223, 2.282129084677053, 2.235286782879782, 2.1798129543409672, 2.1158684288817984, 2.0436081918979516, 1.96318169621133, 1.874733152221798, 1.778401798310177, 1.674322153227182, 1.5626242516034876, 1.4434338643921176, 1.3168727050645797, 1.183058622970063, 1.0421057844365302, 0.8941248430326301, 0.7392230994289373, 0.5775046518938292, 0.4090705377234085, 0.2340188667503329, 0.0524449470802244, -0.13555859607931509, -0.32990170843958677, -0.5304968005403767, -0.7372586475287907, -0.9501042941461674]
# Row 7: [0.0, -0.20179516348097984, -0.41198802013510105, -0.6304160870768336, -0.8569225681421287, -1.0913560707813548, -1.3335703412735593, -1.5834240164684144, -1.8407803911126843, -2.10550719921128, -2.377476408801555, -2.656564028800709, -2.942649927227849, -3.2356176599967674, -3.535354309398097, -3.8417503317945156, -4.154699413730154, -4.474098335943117, -4.799846844755162, -5.131847530409717, -5.470005711766777, -5.814229327049877, -6.164428830277987, -6.520517092889057, -6.882409310429487, -7.250022913831741, -7.623277485061207, -8.002094676860525, -8.386398136483574, -8.776113432820598, -9.17116798719475, -9.571491007262098, -9.977013423967014, -10.387667831372767, -10.80338842927124, -11.224110968248569, -11.649772697270414, -12.080312313517213, -12.51566991436354, -12.955786951496673, -13.40060618692456, -13.850071650831355, -14.304128601186914, -14.762723485085898, -15.225803901558224, -15.693318565975826, -16.1652172758424, -16.641450877902308, -17.12197123668866, -17.606731204077896]
# Row 8: [0.0, -0.3015493345103196, -0.6125791844560694, -0.9328213752594732, -1.2620231561534934, -1.5999458906257547, -1.9463638905172558, -2.3010633755966428, -2.663841541196271, -3.0345057211444133, -3.4128726338576167, -3.798767701147792, -4.192024432114814, -4.59248386348273, -4.999994050942174, -5.414409605510703, -5.835591269644169, -6.263405529849755, -6.697724260876877, -7.13842439921646, -7.585387642628014, -8.03850017275105, -8.497652399550553, -8.962738724398058, -9.433657321012014, -9.91030993227534, -10.392601681113574, -10.880440895170521, -11.37373894290396, -11.872410081362846, -12.376371313486937, -12.885542255101125, -13.39984501045624, -13.919204055239515, -14.443546127441003, -14.972800124318635, -15.506897005956194, -16.045769704552256, -16.58935303861988, -17.137583632713536, -17.69039984113126, -18.247741676271275, -18.809550740947866, -19.37577016399682, -19.94634453992053, -20.521219871145483, -21.100343513680137, -21.683664125579927, -22.27113161763916, -22.862697107145166]
# Row 9: [0.0, -0.08000066352868193, -0.17258873779738387, -0.2773451526026595, -0.3938793218853469, -0.5218262687673857, -0.6608441272258256, -0.8106119608421366, -0.9708278494507132, -1.1412072038678818, -1.3214812758752055, -1.5113958355432664, -1.7107099931442717, -1.9191951466046029, -2.1366340377817745, -2.362819903966613, -2.597555713121087, -2.8406534721576504, -3.0919336003923075, -3.351224360081458, -3.6183613378633135, -3.893186971748218, -4.175550118321005, -4.465305656137047, -4.762314121819423, -5.06644137511336, -5.377558290254294, -5.695540471311546, -6.020267988818954, -6.351625135891245, -6.689500202276743, -7.033785264316347, -7.384375989591611, -7.741171455222357, -8.104073978231805, -8.472988957154628, -8.847824724204555, -9.228492406702784, -9.614905797254266, -10.006981232191125, -10.404637477223078, -10.807795619965617, -11.216378969062268, -11.630312958820033, -12.049525059688428, -12.473944693549242, -12.903503153725877, -13.338133529597306, -13.777770635084524, -14.222350940938675]
# Row 10: [0.0, 0.033436620778201885, 0.049394517106393025, 0.04864394503037328, 0.03188664127460354, -0.00023507113739734686, -0.04713075410802997, -0.10825557309251177, -0.18310501248969047, -0.27121039577462003, -0.3721350612706319, -0.48547107618447005, -0.6108363959264669, -0.7478723954968811, -0.8962417122753008, -1.0556263519541553, -1.225726018744266, -1.4062566362923485, -1.596949032494868, -1.797547766442749, -2.0078100776833656, -2.227504942103776, -2.456412221724364, -2.6943218960049213, -2.941033365056651, -3.1963548172514145, -3.460102652617982, -3.73210095665251, -4.012181019288494, -4.300180893342348, -4.595944989041241, -4.899323701246513, -5.210173064932735, -5.528354437746598, -5.85373420590836, -6.186183511487481, -6.525577999836392, -6.871797584481824, -7.224726228089294, -7.584251738988801, -7.9502655806312506, -8.322662693733859, -8.701341330276659, -9.086202897482396, -9.477151811695425, -9.874095361607381, -10.27694357919758, -10.685609118514417, -11.100007141974254, -11.520055212417398]

# %%
for x in np.arange(16, 17, 0.1):
    print(x,TS(x,N,S,B))
# Out:
# 16.0 -1.225726018744266
# 16.1 -1.2433142418170922
# 16.200000000000003 -1.261006486542814
# 16.300000000000004 -1.278802478781244
# 16.400000000000006 -1.296701945963239
# 16.500000000000007 -1.3147046168619378
# 16.60000000000001 -1.3328102217995899
# 16.70000000000001 -1.351018492376471
# 16.80000000000001 -1.369329161759054
# 16.900000000000013 -1.387741964409412

# %%
# Out:
# 16.0 -3.7724305740531276
# 16.1 -3.802278687630614
# 16.200000000000003 -3.8321961832082607
# 16.300000000000004 -3.8621829290288847
# 16.400000000000006 -3.8922387938152467
# 16.500000000000007 -3.9223636468082237
# 16.60000000000001 -3.9525573577506394
# 16.70000000000001 -3.9828197968769783
# 16.80000000000001 -4.0131508349457645
# 16.900000000000013 -4.04355034318088
